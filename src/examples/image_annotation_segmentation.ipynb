# %% [markdown]
# ### This script shows how we **CREATE** the **TRAINING SET** for **SEGMENTATION** task.

# %%
# Import util script
import sys
sys.path.append('../..')
from src.utils.json2binary import json2binary

# %%
# Just an example. Run in a python script to avoid ../ path
json_path = "../../images/annotated/annotated-T/O. glaberrima/1_2_1_1_1_DSC01251.json"
json2binary(json_path)

# %% [markdown]
# ### Result
#
# Path: images/annotated/annotated-T/O. glaberrima/1_2_1_1_1_DSC01251.jpg
#
# ![1_2_1_1_1_DSC01251.jpg](attachment:1_2_1_1_1_DSC01251.jpg)
#
# Do this for 200 times and feel the pain :grin:
